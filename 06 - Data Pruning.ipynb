# %% [markdown]
# # Your Model is Only as Good as the Data it Learns From
#
# ## Your Data Contains Bugs/Outliers

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.DataFrame([[1,2],[3,6],[5,10],[6,12],[7,14],[32,1],[8,16]])
# with column names for ease of use
df.columns = ['Unique User Agents','Unique IPs']
df.sample(1)
# Out:
#    Unique User Agents  Unique IPs
# 5                  32           1

# %%
df.plot()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# The college campus has thousands of users (and probably a lot of junk traffic with user-agent spoofing), but only 1 outbound IP addresses. This is an example of an outlier that will fool your model into thinking that this is a normal event that has the same wieght as everything else. Before running ML on your data, find the outliers and decide at what point you want to cut off and restrict the anomalies to create a "normalized" set of data.

# %%
df = pd.DataFrame([[1,2],[3,6],[5,10],[6,12],[7,14],[8,16]])
df.columns = ['Unique User Agents','Unique IPs']
df.sample(1)
df.plot()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # TODO: split data into test/train

# %% [markdown]
# ## Next Up
# [Where Do You Go From Here?](/notebooks/07%20-%20From%20Here.ipynb)
